# %% [markdown]
# <a href="https://colab.research.google.com/github/Shadi-Aldbaiss/Python/blob/main/EDA_Iris__By_Shadi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Library :**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Read dataset**

# %%
df=pd.read_csv('/content/iris.csv')

# %% [markdown]
# # **Discovering dataset**

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().mean()*100
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
df.shape
# Out:
# (150, 5)

# %%
df.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# sepal_length
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 6.4     7
# 5.5     7
# 5.8     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 6.2     4
# 4.4     3
# 7.2     3
# 5.9     3
# 6.8     3
# 4.7     2
# 6.6     2
# 4.3     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.1     1
# 7.3     1
# 7.6     1
# 7.4     1
# 7.9     1
# Name: count, dtype: int64

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.054000      3.758667     1.198667     NaN
# std         0.828066     0.433594      1.764420     0.763161     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %% [markdown]
# # **Seprate Numerical data and Categorical Data**

# %%
cat_col=df.select_dtypes(include='object')
num_col=df.select_dtypes(include='number')
print('Categorical Data :',cat_col.columns)
print('Numerical Data :',num_col.columns)
# Out:
# Categorical Data : Index(['species'], dtype='object')
# Numerical Data : Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **Univariate Analysis**

# %%
#histogram data ....continuous
sns.histplot(df['sepal_length'])
plt.title('Histogram')
plt.xlabel('sepal_length')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['sepal_width'])
plt.title('Histogram')
plt.xlabel('sepal_width')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['petal_length'])
plt.title('Histogram')
plt.xlabel('petal_length')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['petal_width'])
plt.title('Histogram')
plt.xlabel('petal_width')
plt.ylabel('Frequency')
plt.show()

# %%
#Density curve (KDE):,numerical data ....continuous
sns.kdeplot(df['sepal_length'], shade=True,color='blue')
plt.title('Density Curve of sepal_length')
plt.xlabel('sepal_length')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-22-a7130ff413a5>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'], shade=True,color='blue')

# %%
#Density curve (KDE):,numerical data ....continuous
sns.kdeplot(df['sepal_width'], shade=True,color='blue')
plt.title('Density Curve of sepal_width')
plt.xlabel('sepal_width')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-23-b1a96adc4c3d>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_width'], shade=True,color='blue')

# %%
#Density curve (KDE):,numerical data ....continuous
sns.kdeplot(df['petal_length'], shade=True,color='blue')
plt.title('Density Curve of petal_length')
plt.xlabel('petal_length')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-24-78204b10b18b>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['petal_length'], shade=True,color='blue')

# %%
#Density curve (KDE):,numerical data ....continuous
sns.kdeplot(df['petal_width'], shade=True,color='blue')
plt.title('Density Curve of petal_width')
plt.xlabel('petal_width')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-25-eadd35a8a5a3>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['petal_width'], shade=True,color='blue')

# %%
#boxplot data ....continuous
sns.boxplot(x=df['sepal_length'])
plt.title('Boxplot of sepal_length')
plt.xlabel('sepal_length')
plt.ylabel('Frequency')
plt.show()

# %%
#boxplot data ....continuous
sns.boxplot(x=df['sepal_width'])
plt.title('Boxplot of sepal_width')
plt.xlabel('sepal_width')
plt.ylabel('Frequency')
plt.show()

# %%
#boxplot data ....continuous
sns.boxplot(x=df['petal_width'])
plt.title('Boxplot of petal_width')
plt.xlabel('petal_width')
plt.ylabel('Frequency')
plt.show()

# %%
#boxplot data ....continuous
sns.boxplot(x=df['petal_length'])
plt.title('Boxplot of petal_length')
plt.xlabel('petal_length')
plt.ylabel('Frequency')
plt.show()

# %%
#violin: data ....continuous
sns.violinplot(x=df['sepal_length'])
plt.title('Violin Plot of sepal_length')
plt.xlabel('sepal_length')
plt.ylabel('Frequency')
plt.show()

# %%
#violin: data ....continuous
sns.violinplot(x=df['sepal_width'])
plt.title('Violin Plot of sepal_width')
plt.xlabel('sepal_width')
plt.ylabel('Frequency')
plt.show()

# %%
#violin: data ....continuous
sns.violinplot(x=df['petal_width'])
plt.title('Violin Plot of petal_width')
plt.xlabel('petal_width')
plt.ylabel('Frequency')
plt.show()

# %%
#violin: data ....continuous
sns.violinplot(x=df['petal_length'])
plt.title('Violin Plot of petal_length')
plt.xlabel('petal_length')
plt.ylabel('Frequency')
plt.show()

# %%
#bar plot :categorical data
sns.countplot(x=df['species'])
plt.title('Bar Plot of species')
plt.xlabel('species')
plt.ylabel('Frequency')
plt.show()

# %%
#pie chart :
labels = ['setosa', 'versicolor','virginica']
#sizes =
colors = ['green', 'red','blue']
explode = (0.1,0.1,0.1)
plt.pie(df['species'].value_counts(), labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Pie Chart of species')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Bivariate Analysis

# %%
#Scatter Plots : num vs num
sns.scatterplot(x=df['sepal_length'], y=df['sepal_width'],hue=df['species'])
plt.title('Scatter Plot')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
#Scatter Plots : num vs num
sns.scatterplot(x=df['petal_length'], y=df['petal_width'],hue=df['species'])
plt.title('Scatter Plot')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
#line plot: num vs num
sns.lineplot(x=df['sepal_length'], y=df['sepal_width'],hue=df['species'])
plt.title('line Plot')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
#line plot: num vs num
sns.lineplot(x=df['petal_length'], y=df['petal_width'],hue=df['species'])
plt.title('line Plot')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
#regression plot:
sns.regplot(x=df['sepal_length'], y=df['sepal_width'],scatter=False)
plt.title('Regression Plot')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
#regression plot:
sns.regplot(x=df['petal_length'], y=df['petal_width'],scatter=False)
plt.title('Regression Plot')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
#pair Plote :
sns.pairplot(df)
plt.show()

# %%
#bar Plot : cat vs cat/Discrete
sns.barplot(x=df['species'], y=df['petal_length'])
plt.title('Bar Plot')
plt.xlabel('species')
plt.ylabel('petal_length')
plt.show()

# %%
#bar Plot : cat vs cat/Discrete
sns.barplot(x=df['species'], y=df['petal_width'])
plt.title('Bar Plot')
plt.xlabel('species')
plt.ylabel('petal_width')
plt.show()

# %%
#bar Plot : cat vs cat/Discrete
sns.barplot(x=df['species'], y=df['sepal_width'])
plt.title('Bar Plot')
plt.xlabel('species')
plt.ylabel('sepal_width')
plt.show()

# %%
#bar Plot : cat vs cat/Discrete
sns.barplot(x=df['species'], y=df['sepal_length'])
plt.title('Bar Plot')
plt.xlabel('species')
plt.ylabel('sepal_length')
plt.show()

# %%
#box Plote : cat vs num
sns.boxplot(x=df['species'], y=df['sepal_length'])
plt.title('Box Plot')
plt.xlabel('species')
plt.ylabel('sepal_length')
plt.show()

# %%
#box Plote : cat vs num
sns.boxplot(x=df['species'], y=df['sepal_width'])
plt.title('Box Plot')
plt.xlabel('species')
plt.ylabel('sepal_width')
plt.show()

# %%
#box Plote : cat vs num
sns.boxplot(x=df['species'], y=df['petal_width'])
plt.title('Box Plot')
plt.xlabel('species')
plt.ylabel('petal_width')
plt.show()

# %%
#box Plote : cat vs num
sns.boxplot(x=df['species'], y=df['petal_length'])
plt.title('Box Plot')
plt.xlabel('species')
plt.ylabel('petal_length')
plt.show()

# %%
# Violin plot :
sns.violinplot(x=df['species'], y=df['sepal_length'])
plt.title('Violin Plot')
plt.xlabel('species')
plt.ylabel('sepal_length')
plt.show()

# %%
# Violin plot :
sns.violinplot(x=df['species'], y=df['sepal_width'])
plt.title('Violin Plot')
plt.xlabel('species')
plt.ylabel('sepal_width')
plt.show()

# %%
sns.violinplot(x=df['species'], y=df['petal_width'])
plt.title('Violin Plot')
plt.xlabel('species')
plt.ylabel('petal_width')
plt.show()

# %%
sns.violinplot(x=df['species'], y=df['petal_length'])
plt.title('Violin Plot')
plt.xlabel('species')
plt.ylabel('petal_length')
plt.show()

# %%
# swarm plot:
sns.swarmplot(x=df['species'], y=df['sepal_length'])
plt.title('Swarm Plot')
plt.xlabel('species')
plt.ylabel('sepal_length')
plt.show()

# %%
# swarm plot:
sns.swarmplot(x=df['species'], y=df['sepal_width'])
plt.title('Swarm Plot')
plt.xlabel('species')
plt.ylabel('sepal_width')
plt.show()

# %%
# swarm plot:
sns.swarmplot(x=df['species'], y=df['petal_width'])
plt.title('Swarm Plot')
plt.xlabel('species')
plt.ylabel('petal_width')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# swarm plot:
sns.swarmplot(x=df['species'], y=df['petal_length'])
plt.title('Swarm Plot')
plt.xlabel('species')
plt.ylabel('petal_length')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Multivariat Analysis:

# %%
#heatmap:
sns.heatmap(num_col.corr(),annot=True,vmin=-1,vmax=1)
plt.title('Heatmap')
plt.show()
